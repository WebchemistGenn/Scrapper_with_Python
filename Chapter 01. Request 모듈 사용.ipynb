# %%
import requests

# %% [markdown]
# ### Get 요청

# %%
url = "https://www.yna.co.kr/view/AKR20211105136900083?input=1179m"
res = requests.get(url)

print(res.status_code)
res.text
# Out:
# 200
# '<!doctype html>\n<html lang="ko" class="ko">\n<head itemscope>\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no">\n<meta name="robots" content="max-image-preview:large, max-video-preview:0">\n<link rel="canonical" id="canonical" href="https://www.yna.co.kr/view/AKR20211105136900083" />\n<meta property="og:url" content="https://www.yna.co.kr/view/AKR20211105136900083" />\n<meta name="twitter:url" content="https://www.yna.co.kr/view/AKR20211105136900083" />\n<meta itemprop="url" content="https://www.yna.co.kr/view/AKR20211105136900083" />\n<link rel="amphtml" href="https://m.yna.co.kr/amp/view/AKR20211105136900083">\n<meta property="fb:app_id" content="1013291918759197" />\n<meta property="fb:pages" content="130229496988833" />\n<meta property="og:type" content="article" />\n<meta name="resource-type" content="article" />\n<meta name="copyright" content="Yonhapnews" />\n<meta property="og:site_name" content="연합뉴스" />\n<meta name="twitter:site" content="@yonhaptweet" />\n<meta property="article:publisher" content="https://www.facebook.com/yonhap" />\n<meta name="twitter:creator" content="@yonhaptweet" />\n<meta property="og:locale" content="ko_KR" />\n<meta itemprop="inLanguage" content="ko_KR" />\n<title>중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스</title>\n<meta property="og:title" content="중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스">\n<meta name="title" content="중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스">\n<meta name="twitter:title" content="중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스">\n<meta itemprop="name" content="중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스">\n<meta itemprop="headline" content="중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스"/>\n<meta property="og:description" content="(베이징=연합뉴스) 조준형 특파원 = 양안(중국 본토와 대만) 갈등이 심화하는 가운데, 중국 정부는 5일 독립을 완고하게 추구하는 대만인에 대해..." />\n<meta name="description" content="(베이징=연합뉴스) 조준형 특파원 = 양안(중국 본토와 대만) 갈등이 심화하는 가운데, 중국 정부는 5일 독립을 완고하게 추구하는 대만인에 대해..." />\n<meta name="twitter:description" content="(베이징=연합뉴스) 조준형 특파원 = 양안(중국 본토와 대만) 갈등이 심화하는 가운데, 중국 정부는 5일 독립을 완고하게 추구하는 대만인에 대해..." />\n<meta itemprop="description" content="(베이징=연합뉴스) 조준형 특파원 = 양안(중국 본토와 대만) 갈등이 심화하는 가운데, 중국 정부는 5일 독립을 완고하게 추구하는 대만인에 대해..." />\n<meta name="twitter:card" content="summary_large_image" />\n<meta name="twitter:image" content="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg">\n<meta property="og:image" content="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg" />\n<meta property="og:image:width" content="640" />\n<meta property="og:image:height" content="285" />\n<meta name="image" content="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg" />\n<meta itemprop="image" content="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg" />\n<meta itemprop="thumbnailUrl" content="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg" />\n<link rel="image_src" href="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg" />\n<meta property="yna:content_id" content="AKR20211105136900083">\n<meta property="article:section" content="국제" />\n<meta itemprop="genre" content="국제" />\n<meta property="article:author" content="조준형" />\n<meta name="author" content="조준형" />\n<meta itemprop="publisher" content="조준형" />\n<meta property="article:author" content="https://www.facebook.com/yonhap" />\n<meta property="article:published_time" content="2021-11-05T17:30:42+09:00" />\n<meta property="article:modified_time" content="2021-11-05T17:30:42+09:00" />\n<link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.yna.co.kr/view/AKR20211105136900083" />\n<meta property="dd:playtime" content="">\n<m ...

# %% [markdown]
# ### Post 요청

# %%
url = "post url"
data = {
    'id': '',
    'pwd': 'T'
}
res = requests.post(url, data=data)
res.text

# %% [markdown]
# ### Header 데이터 이용하기

# %%
url = "https://www.yna.co.kr/view/AKR20211105136900083?input=1179m"
headers = {
    'user-agent': "Mozilla/5.0 (iPhone; CPU iPhone OS 13_2_3 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0.3 Mobile/15E148 Safari/604.1"
}
res = requests.get(url, headers=headers)
res.text
# Out:
# '<!doctype html>\n<html lang="ko" class="ko">\n<head itemscope>\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no">\n<meta name="robots" content="max-image-preview:large, max-video-preview:0">\n<link rel="canonical" id="canonical" href="https://www.yna.co.kr/view/AKR20211105136900083" />\n<meta property="og:url" content="https://www.yna.co.kr/view/AKR20211105136900083" />\n<meta name="twitter:url" content="https://www.yna.co.kr/view/AKR20211105136900083" />\n<meta itemprop="url" content="https://www.yna.co.kr/view/AKR20211105136900083" />\n<link rel="amphtml" href="https://m.yna.co.kr/amp/view/AKR20211105136900083">\n<meta property="fb:app_id" content="1013291918759197" />\n<meta property="fb:pages" content="130229496988833" />\n<meta property="og:type" content="article" />\n<meta name="resource-type" content="article" />\n<meta name="copyright" content="Yonhapnews" />\n<meta property="og:site_name" content="연합뉴스" />\n<meta name="twitter:site" content="@yonhaptweet" />\n<meta property="article:publisher" content="https://www.facebook.com/yonhap" />\n<meta name="twitter:creator" content="@yonhaptweet" />\n<meta property="og:locale" content="ko_KR" />\n<meta itemprop="inLanguage" content="ko_KR" />\n<title>중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스</title>\n<meta property="og:title" content="중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스">\n<meta name="title" content="중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스">\n<meta name="twitter:title" content="중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스">\n<meta itemprop="name" content="중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스">\n<meta itemprop="headline" content="중국 &apos;강성 대만독립분자&apos; 명단 작성…&quot;중국법으로 형사처벌&quot; | 연합뉴스"/>\n<meta property="og:description" content="(베이징=연합뉴스) 조준형 특파원 = 양안(중국 본토와 대만) 갈등이 심화하는 가운데, 중국 정부는 5일 독립을 완고하게 추구하는 대만인에 대해..." />\n<meta name="description" content="(베이징=연합뉴스) 조준형 특파원 = 양안(중국 본토와 대만) 갈등이 심화하는 가운데, 중국 정부는 5일 독립을 완고하게 추구하는 대만인에 대해..." />\n<meta name="twitter:description" content="(베이징=연합뉴스) 조준형 특파원 = 양안(중국 본토와 대만) 갈등이 심화하는 가운데, 중국 정부는 5일 독립을 완고하게 추구하는 대만인에 대해..." />\n<meta itemprop="description" content="(베이징=연합뉴스) 조준형 특파원 = 양안(중국 본토와 대만) 갈등이 심화하는 가운데, 중국 정부는 5일 독립을 완고하게 추구하는 대만인에 대해..." />\n<meta name="twitter:card" content="summary_large_image" />\n<meta name="twitter:image" content="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg">\n<meta property="og:image" content="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg" />\n<meta property="og:image:width" content="640" />\n<meta property="og:image:height" content="285" />\n<meta name="image" content="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg" />\n<meta itemprop="image" content="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg" />\n<meta itemprop="thumbnailUrl" content="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg" />\n<link rel="image_src" href="https://img6.yna.co.kr/etc/inner/KR/2021/11/05/AKR20211105136900083_01_i_P4.jpg" />\n<meta property="yna:content_id" content="AKR20211105136900083">\n<meta property="article:section" content="국제" />\n<meta itemprop="genre" content="국제" />\n<meta property="article:author" content="조준형" />\n<meta name="author" content="조준형" />\n<meta itemprop="publisher" content="조준형" />\n<meta property="article:author" content="https://www.facebook.com/yonhap" />\n<meta property="article:published_time" content="2021-11-05T17:30:42+09:00" />\n<meta property="article:modified_time" content="2021-11-05T17:30:42+09:00" />\n<link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.yna.co.kr/view/AKR20211105136900083" />\n<meta property="dd:playtime" content="">\n<m ...
